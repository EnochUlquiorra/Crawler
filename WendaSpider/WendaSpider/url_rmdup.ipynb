# %%
import numpy as np
import pandas as pd

# %%
a=pd.read_csv('Url.csv',encoding='gbk',error_bad_lines=False,header=None)

# %%
a=a.drop_duplicates(subset=[0])

# %%
a.to_csv('url_sougou.csv',header=None,index=None)

# %%
baidu=pd.read_csv('url_baidu.csv',error_bad_lines=False,header=None)

# %%
baidu_1=baidu[:72500]
baidu_1
# Out:
#                                                        0  \
# 0       https://zhidao.baidu.com/question/131790700.html
# 1       https://zhidao.baidu.com/question/132068294.html
# 2       https://zhidao.baidu.com/question/132218035.html
# 3       https://zhidao.baidu.com/question/132066279.html
# 4       https://zhidao.baidu.com/question/131723505.html
# ...                                                  ...
# 72495  https://zhidao.baidu.com/question/430179839272...
# 72496  https://zhidao.baidu.com/question/164376388523...
# 72497  https://zhidao.baidu.com/question/181486585423...
# 72498  https://zhidao.baidu.com/question/169591773906...
# 72499  https://zhidao.baidu.com/question/987689320682...
#
#                               1                 2
# 0           一般企业应纳税的种类有哪些?_百度知道  zhidao.baidu.com
# 1          商品流通企业交哪些税税率多少？_百度知道  zhidao.baidu.com
# 2                  所得税学习总结_百度知道  zhidao.baidu.com
# 3                 erp 税的计算_百度知道  zhidao.baidu.com
# ...

# %%
baidu_2=baidu[72500:]
baidu_2
# Out:
#                                                         0  \
# 72500   https://zhidao.baidu.com/question/111600733444...
# 72501   https://zhidao.baidu.com/question/557667622193...
# 72502   https://zhidao.baidu.com/question/180159848256...
# 72503   https://zhidao.baidu.com/question/685667439187...
# 72504   https://zhidao.baidu.com/question/211964623390...
# ...                                                   ...
# 145053  https://zhidao.baidu.com/question/717012065218...
# 145054  https://zhidao.baidu.com/question/136644972816...
# 145055  https://zhidao.baidu.com/question/154013419196...
# 145056  https://zhidao.baidu.com/question/204797195029...
# 145057  https://zhidao.baidu.com/question/559465892736...
#
#                                       1                 2
# 72500   上年度收的押金已记收入，3%的税已交，现要退回凭证怎么 ...  zhidao.baidu.com
# 72501    增值税电子普通发票上购买方的名称一栏写的是个人的名字 ...  zhidao.baidu.com
# 72502                重庆国税领取定额票怎么操作_百度知道  zhidao.baidu.com
# ...

# %%
baidu_1.to_csv('url_baidu_1.csv',header=None,index=None)
baidu_2.to_csv('url_baidu_2.csv',header=None,index=None)

# %%
test=baidu[-100:]
test.to_csv('url_baidu_3.csv',header=None,index=None)
